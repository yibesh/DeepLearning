# %% [markdown]
# <a href="https://colab.research.google.com/github/yibesh/DeepLearning/blob/main/NN_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # **Generate toy** **dataset**

# %%
X, y = make_moons(n_samples=500, noise=0.2, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # **Build** **a simple model**

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(2,)),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# # **Compile the model**

# %%
model.compile(optimizer=Adam(0.01), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # **Train the model**

# %%
model.fit(X_train, y_train, epochs=50, verbose=0)

# %% [markdown]
# # **Evaluate**

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {acc * 100:.2f}%")
# Out:
# Test Accuracy: 94.00%

# %% [markdown]
# # **Plot predictions**

# %%
preds = model.predict(X_test).flatten()
plt.scatter(X_test[:, 0], X_test[:, 1], c=(preds > 0.5), cmap='coolwarm')
plt.title("Test Predictions")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
